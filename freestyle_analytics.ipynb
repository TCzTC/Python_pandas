# %% [markdown]
# <a href="https://colab.research.google.com/github/TCzTC/Python_pandas/blob/main/freestyle_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bond = pd.read_csv("/content/jamesbond.csv", index_col="Movie").dropna(how="all").sort_index()
bond.head(5)
# Out:
#                       Year            Bond         Director      Composer  \
# Movie
# A View to a Kill      1985     Roger Moore        John Glen    John Barry
# Casino Royale         2006    Daniel Craig  Martin Campbell  David Arnold
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton    John Barry
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  David Arnold
# Dr. No                1962    Sean Connery    Terence Young  Monty Norman
#
#                                                                  Writer  \
# Movie
# A View to a Kill                    Michael G. Wilson & Richard Maibaum
# Casino Royale                    Neal Purvis, Robert Wade & Paul Haggis
# Diamonds Are Forever                   Richard Maibaum & Tom Mankiewicz
# Die Another Day                             Neal Purvis and Robert Wade
# Dr. No                Richard Maibaum, Johanna Harwood & Berkely Mather
#
#                        Cinematographer  \
# Movie
# ...

# %%
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, A View to a Kill to You Only Live Twice
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   Bond               24 non-null     object
#  2   Director           24 non-null     object
#  3   Composer           24 non-null     object
#  4   Writer             24 non-null     object
#  5   Cinematographer    24 non-null     object
#  6   Depicted_Film_Loc  24 non-null     object
#  7   Shooting_Loc       24 non-null     object
#  8   Bond_Car_MFG       24 non-null     object
#  9   Bond_Girl_Nat      24 non-null     object
#  10  US_Gross           24 non-null     int64
#  11  US_Adj             24 non-null     int64
#  12  World_Gross        24 non-null     int64
#  13  World_Adj          24 non-null     int64
#  14  Budget             24 non-null     int64
# ...

# %%
bond.rename(columns={"Year":"Rok","Bond":"Pepa s pistolí"})
title_change = {"A View to a Kill": "Pohled na zabití"}
bond.rename(index=title_change)
# Out:
#                                  Year            Bond            Director  \
# Movie
# Pohled na zabití                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# License to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond_movies = bond[["Bond","Director","Composer"]]

# %%
bond_movies.head(3)
# Out:
#                               Bond         Director      Composer
# Movie
# A View to a Kill       Roger Moore        John Glen    John Barry
# Casino Royale         Daniel Craig  Martin Campbell  David Arnold
# Diamonds Are Forever  Sean Connery     Guy Hamilton    John Barry

# %%
bond_movies.columns = ["Film","Režieš","Kompozitor"]
bond_movies.head(3)
# Out:
#                               Film           Režieš    Kompozitor
# Movie
# A View to a Kill       Roger Moore        John Glen    John Barry
# Casino Royale         Daniel Craig  Martin Campbell  David Arnold
# Diamonds Are Forever  Sean Connery     Guy Hamilton    John Barry

# %%
bond.drop(columns=["Composer","Cinematographer"])
# Out:
#                                  Year            Bond            Director  \
# Movie
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# License to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
deleted_bondz = bond.drop(index=bond.loc["A View to kill":"Thunderball"].index)
deleted_bondz
# Out:
#                      Year            Bond            Director      Composer  \
# Movie
# A View to a Kill     1985     Roger Moore           John Glen    John Barry
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode  David Arnold
# You Only Live Twice  1967    Sean Connery       Lewis Gilbert    John Barry
#
#                                                   Writer Cinematographer  \
# Movie
# A View to a Kill     Michael G. Wilson & Richard Maibaum       Alan Hume
# Tomorrow Never Dies                      Bruce Feirstein   Robert Elswit
# You Only Live Twice                           Roald Dahl   Freddie Young
#
#                                                     Depicted_Film_Loc  \
# Movie
# A View to a Kill         Russia, Great Britain, France, United States
# Tomorrow Never Dies                 Russia, England, Germany, Vietnam
# You Only Live Twice  United States, Russia, Kazakhstan, Norway, Japan
#
# ...

# %%
bond.sample()
# Out:
#                       Year         Bond       Director         Composer  \
# Movie
# The Spy Who Loved Me  1977  Roger Moore  Lewis Gilbert  Marvin Hamlisch
#
#                                                   Writer Cinematographer  \
# Movie
# The Spy Who Loved Me  Christopher Wood & Richard Maibaum   Claude Renoir
#
#                                                  Depicted_Film_Loc  \
# Movie
# The Spy Who Loved Me  Austria, Russia, Great Britain, Egypt, Italy
#
#                                                            Shooting_Loc  \
# Movie
# The Spy Who Loved Me  England, Switzerland, Canada, Scotland, Egypt,...
#
#                      Bond_Car_MFG               Bond_Girl_Nat  ...  \
# Movie                                                          ...
# The Spy Who Loved Me        Lotus  American, English, Bosnian  ...
#
#                       Film_Length  Avg_User_IMDB  Avg_User_Rtn_Tom  Conquests  \
# Movie
# ...

# %%
bond.sample(3)
# Out:
#                     Year          Bond       Director    Composer  \
# Movie
# Thunderball         1965  Sean Connery  Terence Young  John Barry
# For Your Eyes Only  1981   Roger Moore      John Glen  Bill Conti
# Octopussy           1983   Roger Moore      John Glen  John Barry
#
#                                                                Writer  \
# Movie
# Thunderball                            Richard Maibaum & John Hopkins
# For Your Eyes Only                Michael G. Wilson & Richard Maibaum
# Octopussy           George MacDonald Fraser, Michael G. Wilson & R...
#
#                    Cinematographer  \
# Movie
# Thunderball              Ted Moore
# For Your Eyes Only       Alan Hume
# Octopussy                Alan Hume
#
#                                                     Depicted_Film_Loc  \
# Movie
# Thunderball             France, Great Britain, Bahamas, United States
# For Your Eyes Only  Great Britain, Russia, Spain, Italy, Greece, A...
# ...

# %%
bond.sample(frac=0.25)
# Out:
#                                  Year            Bond       Director  \
# Movie
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Spectre                          2015    Daniel Craig     Sam Mendes
# Die Another Day                  2002  Pierce Brosnan   Lee Tamahori
#
#                                       Composer  \
# Movie
# You Only Live Twice                 John Barry
# Dr. No                            Monty Norman
# From Russia with Love               John Barry
# On Her Majesty's Secret Service     John Barry
# Spectre                          Thomas Newman
# Die Another Day                   David Arnold
#
#                                                                             Writer  \
# Movie
# ...

# %%
bond.sample(n=2, axis="columns")
# Out:
#                                  Top_100  \
# Movie
# A View to a Kill                       1
# Casino Royale                          1
# Diamonds Are Forever                   1
# Die Another Day                        1
# Dr. No                                 0
# For Your Eyes Only                     1
# From Russia with Love                  0
# GoldenEye                              0
# Goldfinger                             1
# License to Kill                        0
# Live and Let Die                       1
# Moonraker                              0
# Octopussy                              1
# On Her Majesty's Secret Service        0
# Quantum of Solace                      1
# Skyfall                                1
# Spectre                                1
# The Living Daylights                   0
# The Man with the Golden Gun            0
# The Spy Who Loved Me                   1
# The World Is Not Enough                0
# Thunderball                            1
# ...

# %%
bond.sample(n=3, axis="index")
# Out:
#              Year          Bond       Director       Composer  \
# Movie
# Dr. No       1962  Sean Connery  Terence Young   Monty Norman
# Thunderball  1965  Sean Connery  Terence Young     John Barry
# Spectre      2015  Daniel Craig     Sam Mendes  Thomas Newman
#
#                                                         Writer  \
# Movie
# Dr. No       Richard Maibaum, Johanna Harwood & Berkely Mather
# Thunderball                     Richard Maibaum & John Hopkins
# Spectre      John Logan & Neal Purvis, Robert Wade & Jez Bu...
#
#                Cinematographer  \
# Movie
# Dr. No               Ted Moore
# Thunderball          Ted Moore
# Spectre      Hoyte van Hoytema
#
#                                              Depicted_Film_Loc  \
# Movie
# Dr. No                                   Great Britain, Jamaic
# Thunderball      France, Great Britain, Bahamas, United States
# Spectre      Mexico, England, Italy, Austria, Morocco, Vati...
#
# ...

# %%
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, A View to a Kill to You Only Live Twice
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   Bond               24 non-null     object
#  2   Director           24 non-null     object
#  3   Composer           24 non-null     object
#  4   Writer             24 non-null     object
#  5   Cinematographer    24 non-null     object
#  6   Depicted_Film_Loc  24 non-null     object
#  7   Shooting_Loc       24 non-null     object
#  8   Bond_Car_MFG       24 non-null     object
#  9   Bond_Girl_Nat      24 non-null     object
#  10  US_Gross           24 non-null     int64
#  11  US_Adj             24 non-null     int64
#  12  World_Gross        24 non-null     int64
#  13  World_Adj          24 non-null     int64
#  14  Budget             24 non-null     int64
# ...

# %%
bond_movies = bond[["Bond","Year","Film_Length"]]
bond_movies.head(3)
# Out:
#                               Bond  Year  Film_Length
# Movie
# A View to a Kill       Roger Moore  1985          131
# Casino Royale         Daniel Craig  2006          144
# Diamonds Are Forever  Sean Connery  1971          120

# %%
bond_movies.sort_values("Film_Length", ascending=False).head(4)
# Out:
#                                            Bond  Year  Film_Length
# Movie
# Spectre                            Daniel Craig  2015          148
# Casino Royale                      Daniel Craig  2006          144
# Skyfall                            Daniel Craig  2012          143
# On Her Majesty's Secret Service  George Lazenby  1969          142

# %%
bond_movies.nlargest(n=4, columns="Film_Length")
# Out:
#                                            Bond  Year  Film_Length
# Movie
# Spectre                            Daniel Craig  2015          148
# Casino Royale                      Daniel Craig  2006          144
# Skyfall                            Daniel Craig  2012          143
# On Her Majesty's Secret Service  George Lazenby  1969          142

# %%
film_length = bond_movies["Film_Length"]
film_length.nsmallest(4)
# Out:
# Movie
# Quantum of Solace        106
# Dr. No                   110
# Goldfinger               110
# From Russia with Love    115
# Name: Film_Length, dtype: int64

# %%
bond_is_craig = bond["Bond"] == "Daniel Craig"
bond_is_craig
# Out:
# Movie
# A View to a Kill                   False
# Casino Royale                       True
# Diamonds Are Forever               False
# Die Another Day                    False
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love              False
# GoldenEye                          False
# Goldfinger                         False
# License to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                   True
# Skyfall                             True
# Spectre                             True
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# Thunderball                        False
# Tomorrow Never Dies                False
# ...

# %%
bond[bond_is_craig]
# Out:
#                    Year          Bond         Director       Composer  \
# Movie
# Casino Royale      2006  Daniel Craig  Martin Campbell   David Arnold
# Quantum of Solace  2008  Daniel Craig     Marc Forster   David Arnold
# Skyfall            2012  Daniel Craig       Sam Mendes  Thomas Newman
# Spectre            2015  Daniel Craig       Sam Mendes  Thomas Newman
#
#                                                               Writer  \
# Movie
# Casino Royale                 Neal Purvis, Robert Wade & Paul Haggis
# Quantum of Solace        Paul Haggis and Neal Purvis and Robert Wade
# Skyfall                        Neal Purvis, Robert Wade & John Logan
# Spectre            John Logan & Neal Purvis, Robert Wade & Jez Bu...
#
#                      Cinematographer  \
# Movie
# Casino Royale            Phil Méheux
# Quantum of Solace   Roberto Schaefer
# Skyfall                Roger Deakins
# Spectre            Hoyte van Hoytema
#
# ...

# %%
bond.where(bond_is_craig).dropna()
# Out:
#                      Year          Bond         Director       Composer  \
# Movie
# Casino Royale      2006.0  Daniel Craig  Martin Campbell   David Arnold
# Quantum of Solace  2008.0  Daniel Craig     Marc Forster   David Arnold
# Skyfall            2012.0  Daniel Craig       Sam Mendes  Thomas Newman
# Spectre            2015.0  Daniel Craig       Sam Mendes  Thomas Newman
#
#                                                               Writer  \
# Movie
# Casino Royale                 Neal Purvis, Robert Wade & Paul Haggis
# Quantum of Solace        Paul Haggis and Neal Purvis and Robert Wade
# Skyfall                        Neal Purvis, Robert Wade & John Logan
# Spectre            John Logan & Neal Purvis, Robert Wade & Jez Bu...
#
#                      Cinematographer  \
# Movie
# Casino Royale            Phil Méheux
# Quantum of Solace   Roberto Schaefer
# Skyfall                Roger Deakins
# Spectre            Hoyte van Hoytema
#
# ...

# %%
bond["Bond"].apply(len)

def rank_movie(row):
  year = row.loc["Year"]
  bond_actor = row.loc["Bond"]

  if year >= 1990 and year <= 1999:
    return "Best Bonds"

  if bond_actor == "Daniel Craig":
    return "Best Actor"

  return "no description"

bond.apply(rank_movie, axis="columns")
# Out:
# Movie
# A View to a Kill                   no description
# Casino Royale                          Best Actor
# Diamonds Are Forever               no description
# Die Another Day                    no description
# Dr. No                             no description
# For Your Eyes Only                 no description
# From Russia with Love              no description
# GoldenEye                              Best Bonds
# Goldfinger                         no description
# License to Kill                    no description
# Live and Let Die                   no description
# Moonraker                          no description
# Octopussy                          no description
# On Her Majesty's Secret Service    no description
# Quantum of Solace                      Best Actor
# Skyfall                                Best Actor
# Spectre                                Best Actor
# The Living Daylights               no description
# The Man with the Golden Gun        no description
# ...
